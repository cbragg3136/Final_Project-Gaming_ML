# %%
# Down-sampling involves randomly removing observations from the majority class 
# to prevent its signal from dominating the learning algorithm.
# Most common method is resampling without replacement

# - First, we'll separate observations from each class into different DataFrames.
# - Next, we'll resample the majority class without replacement, setting the number 
# of samples to match that of the minority class.
# - Finally, we'll combine the down-sampled majority class DataFrame with 
# the original minority class DataFrame.

# %%
# load necessary python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# module for resampling
from sklearn.utils import resample

# %%
# os.getcwd()

# %%
# os.listdir(os.getcwd())

# %%
# read the csv x_data file into Pandas 

all_param_df = pd.read_csv("..\\reduced_data\\all_param_binary_tags.csv")
all_param_df.shape
# Out:
# (39624, 351)

# %%
# separate classes in dataframes of success/failure
df_fail = all_param_df[all_param_df.suc_class==0]
df_succ = all_param_df[all_param_df.suc_class==1]

# %%
df_fail.shape
# Out:
# (38818, 351)

# %%
df_succ.shape
# Out:
# (806, 351)

# %%
# Downsample Majority class
df_fail_downsample = resample(df_fail, replace=False, n_samples=1000, random_state=2)

# combine success with downsampled majority class into new dataframe
df_downsampled = pd.concat([df_fail_downsample, df_succ])

# display new class counts
df_downsampled.suc_class.value_counts()
# Out:
# 0    1000
# 1     806
# Name: suc_class, dtype: int64

# %%
# # reindex the new upsampled dataframe
# df_upsampled.reindex()

# %%
# df_upsampled

# %%
# # read the csv y_data file into Pandas 
# y_parm_df = pd.read_csv("reduced_data\\y_params.csv")
# y_parm_df.shape

# %%
# using binary classification for logistic regression
y_class = df_downsampled['suc_class']

# %%
y_class
# Out:
# 13716    0
# 4622     0
# 1350     0
# 30223    0
# 23274    0
#         ..
# 39619    1
# 39620    1
# 39621    1
# 39622    1
# 39623    1
# Name: suc_class, Length: 1806, dtype: int64

# %%
# create new X parameters df
x_data = df_downsampled.drop(['appid','maxccu','success_class','suc_class','followers']  , axis=1)

# %%
x_data.shape
# Out:
# (1806, 346)

# %%
# define training and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_class, random_state=5)

# %%
# baseline example
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Train model
y = y_train
X = X_train

clf_2 = LogisticRegression(max_iter=1000).fit(X, y)
# Out:
# C:\Users\wavau\anaconda3\envs\pythondata\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Apply fitted model to test data - what accuracy?
print(f"Training Data Score: {clf_2.score(X_train, y_train)}")
print(f"Testing Data Score: {clf_2.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9194977843426884
# Testing Data Score: 0.9004424778761062

# %%
# Understand precision, recall, f1 score with classification report for logistic classification
from sklearn.metrics import classification_report
predictions = clf_2.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       248
#            1       0.93      0.84      0.88       204
#
#     accuracy                           0.90       452
#    macro avg       0.91      0.89      0.90       452
# weighted avg       0.90      0.90      0.90       452

# %%
# thinking about baseline results:
# Support is balanced due to sampling adjustments
# Percision: for no success: 89%, for successful games: 87%
# Recall: Fraction of positives found, 89% for 0, 87% for 1
# f1 score: 88%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = clf_2.predict(X_test)
cm2 = confusion_matrix(y_test, y_pred.round())
sns.heatmap(cm2, annot=True, fmt=".0f")
# Out:
# <AxesSubplot:>

# %%
# # print(clf_2.coef_)
# # evaluate feature importance from X parameters
# features_df = pd.DataFrame(zip(x_data.columns, clf_2.coef_[1]))

# # # sort by feature importance 
# # features_df = features_df.sort_values(by=[1], ascending=False)

print(x_data.columns.shape, clf_2.coef_.shape)
new_col = np.reshape(clf_2.coef_, -1)
print(new_col.shape)
features_list = pd.DataFrame(zip(x_data.columns, new_col))
features_list = features_list.sort_values(by=[1], ascending=False)

import pandas
pandas.set_option('display.max_rows', 346)
features_list
# Out:
# (346,) (1, 346)
# (346,)
#                                      0         1
# 160                            tagjrpg  1.011444
# 227                tagwalkingsimulator  0.932186
# 342                         tagclicker  0.868764
# 108                     tagmultiplayer  0.843057
# 244                       taghanddrawn  0.787413
# 88                            tagspace  0.751584
# 150                       tagshootemup  0.730061
# 130                           tagfunny  0.729323
# 56                          tagfantasy  0.599540
# 261                      tagilluminati  0.597134
# 13                            tagindie  0.541266
# 101              tagthirdpersonshooter  0.535215
# 111                           tagscifi  0.529996
# 115                   tagpixelgraphics  0.527371
# 271                     tagleveleditor  0.524722
# 152                        tagcolorful  0.524161
# 74              tagpsychologicalhorror  0.521239
# 51                        tagturnbased  0.495806
# 262                      tagcontroller  0.487802
# 232                             tag0ir  0.487710
# 33                     taghackandslash  0.479095
# 215                        tagrpgmaker  0.467924
# 345                          tagvronly  0.447572
# 110                     tagcompetitive  0.441180
# 320                     tagtacticalrpg  0.434108
# 205                     tagdestruction  0.428085
# 114                       tagroguelite  0.427004
# 226                       tagisometric  0.424736
# 181                         tagtopdown  0.399488
# 200                           tagblood  0.396959
# 43                         tagcardgame  0.390969
# 283                           tagmemes  0.370898
# 158                        tagassassin  0.359132
# 81                tagturnbasedstrategy  0.358663
# 324                        tagwordgame  0.355811
# 57                             tagcoop  0.336182
# 100                 tagrealtimetactics  0.332165
# 278                          tagdemons  0.330794
# 94                              tagpvp  0.326775
# 272  tagmusicbasedproceduralgeneration  0.311421
# 275              tagresourcemanagement  0.305708
# 322                     tagagriculture  0.304090
# 34                          tagwestern  0.294666
# 148                        tagepisodic  0.289380
# 60                          tagclassic  0.286990
# 64                       tagpointclick  0.283229
# 87                           tagmmorpg  0.272406
# 328                        tag3dvision  0.267016
# 274                          tagrunner  0.261402
# 290              tagvillainprotagonist  0.251227
# 50                              tagrts  0.245592
# 16                       tagsimulation  0.237348
# 223                tagguncustomization  0.233452
# 117                  tagsurvivalhorror  0.230917
# 317                      tagdarkcomedy  0.223045
# 97                     tagsidescroller  0.220743
# 266                     tagcultclassic  0.217878
# 37                         tagrelaxing  0.213474
# 31                          tagdriving  0.212121
# 6                            tagaction  0.210564
# 38                          tagzombies  0.206016
# 237                   tagchoicesmatter  0.205015
# 27                            tagmusic  0.199420
# 177          tagcharactercustomization  0.193888
# 219                          tagremake  0.192826
# 85                        tagcomicbook  0.191301
# 103                 tagpostapocalyptic  0.183832
# 121                       tagdifficult  0.181686
# 217                       tagdetective  0.181263
# 154                     tagcitybuilder  0.178937
# 193                       tagnarration  0.176301
# 240                          tagnudity  0.175274
# 325                            tagnsfw  0.172162
# 92                           tagarcade  0.171958
# 206                      tagconspiracy  0.170671
# 295                         tagamerica  0.162435
# 68                      tagpsychedelic  0.162074
# 229                          tagmining  0.157687
# 301    tagintentionallyawkwardcontrols  0.153184
# 236                           tagcrime  0.152493
# 29                     tagmetroidvania  0.149796
# 306               tagsilentprotagonist  0.146772
# 174                     tagreplayvalue  0.137665
# 90                       tagpermadeath  0.137290
# 102                     tagexploration  0.137100
# 141                    tagsingleplayer  0.134899
# 41                           tagpuzzle  0.133018
# 122                         tagparkour  0.131114
# 234             taginventorymanagement  0.130419
# 66                         tagtactical  0.126016
# 26                           tagtrains  0.122665
# 145                       tagactionrpg  0.121027
# 156                            taggore  0.111065
# 132                       tagcinematic  0.106641
# 91                        tagboardgame  0.105392
# 40                              tagfps  0.105134
# 286                    tagsupernatural  0.104760
# 140                       tagrealistic  0.102958
# 53                           tagsoccer  0.096513
# 253               tagfemaleprotagonist  0.096146
# 247                     tagmartialarts  0.095459
# 86                           tagrhythm  0.093775
# 294                      tagmanagement  0.093515
# 186                       tagpolitical  0.093242
# 142                           tagchess  0.092624
# 125                        tagthriller  0.088331
# 203                             tagmod  0.083637
# 54                            tagheist  0.082916
# 310                      tagwerewolves  0.081645
# 222                          tagrobots  0.080328
# 337                          taggaming  0.079871
# 139                        tagmedieval  0.078840
# 70                          taghexgrid  0.075517
# 165                         tagcartoon  0.074622
# 14                      tagearlyaccess  0.067973
# 105                       taglocalcoop  0.060589
# 307                       tagmythology  0.059498
# 73                   tagdungeoncrawler  0.055199
# 281                tagdynamicnarration  0.054508
# 260                    taglovecraftian  0.052984
# 277                 tagtradingcardgame  0.052427
# 257                    tagbasebuilding  0.050106
# 35                        taggamemaker  0.049030
# 246                           tagnaval  0.043976
# 126                           taganime  0.042771
# 71                             tagmoba  0.042551
# 305                         tagfishing  0.040223
# 62                        tagopenworld  0.038023
# 45                         tagmoddable  0.037620
# 164                 tagquicktimeevents  0.036840
# 296                           tagtanks  0.027186
# 46                               tag4x  0.025682
# 7                         tagadventure  0.025365
# 214                    tagarenashooter  0.025253
# 10                       tagfreetoplay  0.024417
# 187                          tagparody  0.020275
# 312                        taglemmings  0.018920
# 287                     tagsplitscreen  0.017137
# 3                          maxdiscount  0.015098
# 153                 tagturnbasedcombat  0.013690
# 44                           taghorror  0.013050
# 72                           tagcomedy  0.012905
# 280                         taghunting  0.011550
# 159                        tagabstract  0.007329
# 1                             negative  0.002347
# 254                        tagfootball  0.001374
# 0                             positive  0.000128
# 4                            totaltags  0.000104
# 259                          tagsniper  0.000075
# 308                        taggambling  0.000030
# 120                         tagvampire  0.000026
# 332                         tagforeign  0.000002
# 256                         tagbowling  0.000000
# 319                       taglaracroft  0.000000
# 323                        tagminigolf  0.000000
# 61                           tagbatman  0.000000
# 183                            tag6dof  0.000000
# 78                         tagstarwars  0.000000
# 331                       tagwrestling  0.000000
# 316                         tagcycling  0.000000
# 210                       tagbenchmark  0.000000
# 336                   tagphilisophical  0.000000
# 340                     tagfeaturefilm  0.000000
# 341                    tagsteammachine  0.000000
# 343                        taghardware  0.000000
# 344                        tag360video  0.000000
# 2                             maxprice -0.000021
# 79                             taglego -0.000731
# 167                     tagdarkfantasy -0.001251
# 127                      tagminimalist -0.001457
# 252                     tagcrowdfunded -0.001829
# 297                         tagsailing -0.004847
# 76                            tagvoxel -0.006045
# 133                      tagworldwarii -0.014670
# 202                   taggamesworkshop -0.017659
# 293                    tagwarhammer40k -0.018942
# 334                        tagspelling -0.019724
# 201                         taggodgame -0.019832
# 173                           tagmovie -0.020333
# 96                     tagbasedona0vel -0.022573
# 282                      tagexperience -0.027759
# 314                            tagpool -0.029475
# 98                       tagvisual0vel -0.029901
# 231                          taghorses -0.029923
# 263               taggridbasedmovement -0.031415
# 304                     tagdocumentary -0.031417
# 270                         tagtrackir -0.031826
# 131                   tagtranshumanism -0.032683
# 95                        tagsteampunk -0.038991
# 175                            tagcute -0.039190
# 20                     tagphotoediting -0.039242
# 163                    tagcoopcampaign -0.040047
# 298                    tagexperimental -0.040351
# 311                     tagstrategyrpg -0.042276
# 176                       tag2dfighter -0.044788
# 195                     tagkickstarter -0.046061
# 248                            tagrome -0.047988
# 136                        tagrealtime -0.050104
# 179                tagtwinstickshooter -0.050829
# 84                       tagbasketball -0.053107
# 24                    tagwebpublishing -0.056845
# 168                       tagswordplay -0.057307
# 65                         tagcrafting -0.058678
# 333                  tagonrailsshooter -0.059668
# 302                          tagflight -0.060774
# 185                      tagcapitalism -0.061323
# 318                     tagunderground -0.069170
# 8                tagdesignillustration -0.069509
# 291                        tagtutorial -0.069648
# 327                    tagvoicecontrol -0.069946
# 265                           tag1980s -0.070462
# 269                        tagsoftware -0.071210
# 147                            tagloot -0.071400
# 47                        tagsuperhero -0.071520
# 284                      tagtimetravel -0.074486
# 230                           tagdrama -0.080415
# 182                           tagmechs -0.082490
# 313          tagasynchro0usmultiplayer -0.086295
# 112                          taggothic -0.087270
# 309                        tagspacesim -0.090320
# 198                         tagcoldwar -0.098913
# 299                 taggamedevelopment -0.100019
# 289                       tagmouseonly -0.102165
# 239                tagtimemanipulation -0.102185
# 338                           tagfaith -0.103119
# 250                            taggolf -0.107942
# 124                           tagmagic -0.108567
# 192                         tagesports -0.108597
# 83                         tagfighting -0.109590
# 242                            tagmars -0.112524
# 169                  tagtopdownshooter -0.116008
# 107                        taglorerich -0.116632
# 52                              tagwar -0.121579
# 75                          tagsokoban -0.122828
# 5                          tagstrategy -0.124820
# 228                       tagdarkhumor -0.125461
# 190                             tag25d -0.129115
# 69                        tagroguelike -0.132747
# 315                             tagfmv -0.136048
# 25                 tagsoftwaretraining -0.137149
# 197                        tagdi0saurs -0.138227
# 170                         tagviolent -0.139696
# 118                      taghistorical -0.142573
# 238                         tagpinball -0.145036
# 55                          tagpirates -0.149615
# 134                      tagclassbased -0.153371
# 196                     tagscoreattack -0.153412
# 267          tagartificialintelligence -0.153570
# 216                          tagmature -0.158135
# 255                          taglinear -0.159262
# 15                           tagcasual -0.159327
# 221                         tagmystery -0.163622
# 22                  tagaudioproduction -0.164932
# 249                 tagmultipleendings -0.166605
# 225                      tagbullettime -0.167346
# 99                          tagsandbox -0.168488
# 146                           tagshort -0.171943
# 149                        tagstylized -0.172305
# 268                      tagsoundtrack -0.172564
# 326                   tagtouchfriendly -0.176948
# 49                           tagtyping -0.178450
# 330                           tagotome -0.181597
# 208                      tagtimeattack -0.184831
# 128                 tagactionadventure -0.185426
# 220                       tagteambased -0.186737
# 300                tagturnbasedtactics -0.189219
# 335                           tagbikes -0.191817
# 245                        tag0nlinear -0.197480
# 188                      tagbullethell -0.203855
# 218                          tagmodern -0.205963
# 264                         tagoffroad -0.218553
# 211                     tagprogramming -0.221879
# 171                         tagwargame -0.222069
# 39                         tagsurvival -0.226297
# 21                taganimationmodeling -0.231738
# 162          tagchooseyourownadventure -0.232579
# 339                  tagmysterydungeon -0.234712
# 251               tagrealtimewithpause -0.236312
# 42                           tagmatch3 -0.240437
# 144                         tagtrading -0.245044
# 28                       tagplatformer -0.245827
# 273                   taginvestigation -0.247206
# 180                tagspectaclefighter -0.256666
# 288              taginteractivefiction -0.260480
# 19                  tagvideoproduction -0.260687
# 11                              tagrpg -0.266172
# 36                           tagsatire -0.266928
# 137                     tagatmospheric -0.269686
# 17                           tagracing -0.275646
# 161                            tagcrpg -0.276531
# 32                     tagtowerdefense -0.277629
# 209                    tag3dplatformer -0.279553
# 329                       tagtextbased -0.280360
# 67                          tagsurreal -0.280519
# 48                           tagaliens -0.285626
# 241                           tag1990s -0.288429
# 194            tagproceduralgeneration -0.295760
# 30                         tagbuilding -0.296824
# 189                         tagromance -0.297522
# 204                  tagfamilyfriendly -0.298913
# 89                  taggreatsoundtrack -0.306475
# 58                          tagstealth -0.308203
# 191                       tagdystopian -0.313532
# 303                    tagconversation -0.315732
# 184                    tag4playerlocal -0.317538
# 166                tagalternatehistory -0.317915
# 207                       tagworldwari -0.317931
# 276                      tagunderwater -0.319610
# 63                      tagthirdperson -0.325983
# 178                        tagpolitics -0.327270
# 123                         tagdragons -0.328138
# 113             tagcharacteractiongame -0.335624
# 212                         taghacking -0.338139
# 157                   taggrandstrategy -0.346083
# 12             tagmassivelymultiplayer -0.359498
# 172                          tageco0my -0.366728
# 199                   tagpsychological -0.370443
# 119                           tagretro -0.371411
# 9                         tagutilities -0.373052
# 224                         tagscience -0.378900
# 135                        tagbeatemup -0.384125
# 151                      tagfuturistic -0.386521
# 18                           tagsports -0.392525
# 243                             tagpve -0.397986
# 104                     tagfirstperson -0.432201
# 109                              tag2d -0.438051
# 116                         tagphysics -0.460831
# 213                tagpuzzleplatformer -0.464770
# 285                   tagpartybasedrpg -0.465270
# 235                       tagdiplomacy -0.489464
# 292                   tagsexualcontent -0.498751
# 59                            tagninja -0.500359
# 155                            tagdark -0.523376
# 143                        tagcartoony -0.563099
# 77                        tagfastpaced -0.571287
# 80                      taghidde0bject -0.585341
# 233                           taglogic -0.599592
# 93                          tagshooter -0.601795
# 23                        tageducation -0.602177
# 129                       tagcyberpunk -0.633239
# 138                        tagmilitary -0.643910
# 106                      tagonlinecoop -0.686175
# 279                       tagdatingsim -0.707810
# 82                        tagstoryrich -0.787139
# 321                              tagvr -0.974201
# 258                taglocalmultiplayer -1.109100
