# %%
# Down-sampling involves randomly removing observations from the majority class 
# to prevent its signal from dominating the learning algorithm.
# Most common method is resampling without replacement

# - First, we'll separate observations from each class into different DataFrames.
# - Next, we'll resample the majority class without replacement, setting the number 
# of samples to match that of the minority class.
# - Finally, we'll combine the down-sampled majority class DataFrame with 
# the original minority class DataFrame.

# %%
# load necessary python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# module for resampling
from sklearn.utils import resample

# %%
# os.getcwd()

# %%
# os.listdir(os.getcwd())

# %%
# read the csv x_data file into Pandas 

all_param_df = pd.read_csv("..\\reduced_data\\steam_all_param_merged_reduced.csv")
all_param_df.shape
# Out:
# (31576, 357)

# %%
# separate classes in dataframes of success/failure
df_fail = all_param_df[all_param_df.suc_class==0]
df_succ = all_param_df[all_param_df.suc_class==1]

# %%
df_fail.shape
# Out:
# (30773, 357)

# %%
df_succ.shape
# Out:
# (803, 357)

# %%
# Downsample Majority class
df_fail_downsample = resample(df_fail, replace=False, n_samples=1000, random_state=2)

# combine success with downsampled majority class into new dataframe
df_downsampled = pd.concat([df_fail_downsample, df_succ])

# display new class counts
df_downsampled.suc_class.value_counts()
# Out:
# 0    1000
# 1     803
# Name: suc_class, dtype: int64

# %%
# # reindex the new upsampled dataframe
# df_upsampled.reindex()

# %%
# df_upsampled

# %%
# # read the csv y_data file into Pandas 
# y_parm_df = pd.read_csv("reduced_data\\y_params.csv")
# y_parm_df.shape

# %%
# using binary classification for logistic regression
y_class = df_downsampled['suc_class']

# %%
y_class
# Out:
# 11068    0
# 545      0
# 28858    0
# 26054    0
# 6336     0
#         ..
# 29711    1
# 30453    1
# 30489    1
# 30551    1
# 31368    1
# Name: suc_class, Length: 1803, dtype: int64

# %%
# create new X parameters df
x_data = df_downsampled.drop(['appid','maxccu','success_class','suc_class','followers','positive_y', 'negative_y', 'totaltags', 'recommendations', 'positive_x', 'negative_x']  , axis=1)

# %%
x_data.shape
# Out:
# (1803, 346)

# %%
#label encode the developer name

# %%
x_data['developer']=x_data['developer'].astype('category')

# %%
x_data['developer']=x_data['developer'].cat.codes
x_data.head()
# Out:
#        metascore  developer              publisher  maxprice  maxdiscount  \
# 11068          0        326              EmmyGames         0            0
# 545           76        934  Daybreak Game Company      1499           90
# 28858          0       1329            Tomas Gomez      1499           25
# 26054          0         27               A Nostru       199           75
# 6336           0        567             Guru Games         0            0
#
#        tagstrategy  tagaction  tagadventure  tagdesignillustration  \
# 11068            0         29             0                      0
# 545            189        843            81                      0
# 28858            0         88             0                      0
# 26054            0          0             0                      0
# 6336             0         43            48                      0
#
#        tagutilities  ...  tagphilisophical  taggaming  tagfaith  \
# 11068             0  ...                 0          0         0
# 545               0  ...                 0          0         0
# 28858             0  ...                 0          0         0
# 26054             0  ...                 0          0         0
# 6336              0  ...                 0          0         0
#
#        tagmysterydungeon  tagfeaturefilm  tagsteammachine  tagclicker  \
# 11068                  0               0                0           0
# 545                    0               0                0           0
# 28858                  0               0                0           0
# 26054                  0               0                0           0
# 6336                   0               0                0           0
#
#        taghardware  tag360video  tagvronly
# 11068            0            0          0
# 545              0            0          0
# 28858            0            0          1
# 26054            0            0          0
# 6336             0            0          0
#
# [5 rows x 346 columns]

# %%
#label encode the publisher name

# %%
x_data['publisher']=x_data['publisher'].astype('category')

# %%
x_data['publisher']=x_data['publisher'].cat.codes
x_data.head()
# Out:
#        metascore  developer  publisher  maxprice  maxdiscount  tagstrategy  \
# 11068          0        326        331         0            0            0
# 545           76        934        270      1499           90          189
# 28858          0       1329       1083      1499           25            0
# 26054          0         27         35       199           75            0
# 6336           0        567        452         0            0            0
#
#        tagaction  tagadventure  tagdesignillustration  tagutilities  ...  \
# 11068         29             0                      0             0  ...
# 545          843            81                      0             0  ...
# 28858         88             0                      0             0  ...
# 26054          0             0                      0             0  ...
# 6336          43            48                      0             0  ...
#
#        tagphilisophical  taggaming  tagfaith  tagmysterydungeon  \
# 11068                 0          0         0                  0
# 545                   0          0         0                  0
# 28858                 0          0         0                  0
# 26054                 0          0         0                  0
# 6336                  0          0         0                  0
#
#        tagfeaturefilm  tagsteammachine  tagclicker  taghardware  tag360video  \
# 11068               0                0           0            0            0
# 545                 0                0           0            0            0
# 28858               0                0           0            0            0
# 26054               0                0           0            0            0
# 6336                0                0           0            0            0
#
#        tagvronly
# 11068          0
# 545            0
# 28858          1
# 26054          0
# 6336           0
#
# [5 rows x 346 columns]

# %%
# define training and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_class, random_state=5)

# %%
# baseline example
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Pre-processing  - scale the data using the MinMaxScaler and perform some feature selection

from sklearn.preprocessing import MinMaxScaler
x_scaler = MinMaxScaler().fit(X_train)

# %%
# apply the trained scales (MinMax) to the training and testing data

X_train_scaled = x_scaler.transform(X_train)
X_test_scaled = x_scaler.transform(X_test)

# %%
# Train model
y = y_train
X = X_train_scaled

clf_2 = LogisticRegression(max_iter=1000).fit(X, y)

# %%
# Apply fitted model to test data - what accuracy?
print(f"Training Data Score: {clf_2.score(X_train, y_train)}")
print(f"Testing Data Score: {clf_2.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.4948224852071006
# Testing Data Score: 0.7339246119733924

# %%
# Understand precision, recall, f1 score with classification report for logistic classification
from sklearn.metrics import classification_report
predictions = clf_2.predict(X_test_scaled)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80       250
#            1       0.88      0.47      0.61       201
#
#     accuracy                           0.73       451
#    macro avg       0.78      0.71      0.70       451
# weighted avg       0.77      0.73      0.71       451

# %%
# thinking about baseline results:
# Support is balanced due to sampling adjustments
# Percision: for no success: 75%, for successful games: 95%
# Recall: Fraction of positives found, 98% for 0, 61% for 1
# f1 score: 81%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = clf_2.predict(X_test_scaled)
cm2 = confusion_matrix(y_test, y_pred.round())
sns.heatmap(cm2, annot=True, fmt=".0f")
# Out:
# <AxesSubplot:>

# %%
# Co-efficient importance

print(x_data.columns.shape, clf_2.coef_.shape)
new_col = np.reshape(clf_2.coef_, -1)
print(new_col.shape)
features_list = pd.DataFrame(zip(x_data.columns, new_col))
features_list = features_list.sort_values(by=[1], ascending=False)

import pandas
pandas.set_option('display.max_rows', 346)
features_list
# Out:
# (346,) (1, 346)
# (346,)
#                                      0         1
# 141                    tagsingleplayer  2.970766
# 6                            tagaction  2.419365
# 0                            metascore  2.340664
# 14                      tagearlyaccess  1.782649
# 62                        tagopenworld  1.668977
# 11                              tagrpg  1.653654
# 7                         tagadventure  1.648538
# 342                         tagclicker  1.584710
# 5                          tagstrategy  1.427013
# 83                         tagfighting  1.394177
# 57                             tagcoop  1.257121
# 89                  taggreatsoundtrack  1.247545
# 104                     tagfirstperson  1.189333
# 108                     tagmultiplayer  1.168664
# 283                           tagmemes  1.127119
# 247                     tagmartialarts  1.034024
# 63                      tagthirdperson  1.021686
# 16                       tagsimulation  1.012852
# 93                          tagshooter  0.977861
# 15                           tagcasual  0.966124
# 137                     tagatmospheric  0.929090
# 277                 tagtradingcardgame  0.915650
# 12             tagmassivelymultiplayer  0.893305
# 13                            tagindie  0.891773
# 87                           tagmmorpg  0.811973
# 262                      tagcontroller  0.810468
# 328                        tag3dvision  0.797204
# 82                        tagstoryrich  0.780020
# 91                        tagboardgame  0.769496
# 65                         tagcrafting  0.762066
# 88                            tagspace  0.752230
# 160                            tagjrpg  0.749976
# 30                         tagbuilding  0.736166
# 156                            taggore  0.728726
# 177          tagcharactercustomization  0.723451
# 204                  tagfamilyfriendly  0.718141
# 139                        tagmedieval  0.717617
# 40                              tagfps  0.711585
# 111                           tagscifi  0.707578
# 182                           tagmechs  0.704045
# 126                           taganime  0.701369
# 257                    tagbasebuilding  0.693035
# 297                         tagsailing  0.692932
# 294                      tagmanagement  0.692088
# 205                     tagdestruction  0.687938
# 293                    tagwarhammer40k  0.677998
# 214                    tagarenashooter  0.676395
# 216                          tagmature  0.672963
# 18                           tagsports  0.669514
# 158                        tagassassin  0.668767
# 121                       tagdifficult  0.668520
# 56                          tagfantasy  0.662591
# 324                        tagwordgame  0.646868
# 280                         taghunting  0.643573
# 101              tagthirdpersonshooter  0.634779
# 51                        tagturnbased  0.633569
# 79                             taglego  0.621207
# 259                          tagsniper  0.617763
# 305                         tagfishing  0.612156
# 310                      tagwerewolves  0.608773
# 3                             maxprice  0.606500
# 301    tagintentionallyawkwardcontrols  0.605432
# 202                   taggamesworkshop  0.580505
# 58                          tagstealth  0.578675
# 170                         tagviolent  0.576632
# 296                           tagtanks  0.576412
# 99                          tagsandbox  0.573241
# 154                     tagcitybuilder  0.572930
# 337                          taggaming  0.560125
# 105                       taglocalcoop  0.553806
# 55                          tagpirates  0.527282
# 43                         tagcardgame  0.510626
# 285                   tagpartybasedrpg  0.510368
# 317                      tagdarkcomedy  0.499908
# 199                   tagpsychological  0.499313
# 53                           tagsoccer  0.493248
# 90                       tagpermadeath  0.492285
# 84                       tagbasketball  0.490027
# 227                tagwalkingsimulator  0.489262
# 48                           tagaliens  0.464325
# 8                tagdesignillustration  0.458074
# 169                  tagtopdownshooter  0.458013
# 229                          tagmining  0.438288
# 261                      tagilluminati  0.438125
# 321                              tagvr  0.433907
# 50                              tagrts  0.431053
# 77                        tagfastpaced  0.430991
# 60                          tagclassic  0.428116
# 237                   tagchoicesmatter  0.420022
# 163                    tagcoopcampaign  0.416877
# 307                       tagmythology  0.415616
# 106                      tagonlinecoop  0.413468
# 153                 tagturnbasedcombat  0.413146
# 275              tagresourcemanagement  0.412461
# 74              tagpsychologicalhorror  0.409633
# 240                          tagnudity  0.397554
# 39                         tagsurvival  0.394533
# 292                   tagsexualcontent  0.390604
# 38                          tagzombies  0.387651
# 102                     tagexploration  0.379366
# 130                           tagfunny  0.368114
# 185                      tagcapitalism  0.364104
# 168                       tagswordplay  0.357988
# 117                  tagsurvivalhorror  0.357856
# 332                         tagforeign  0.344105
# 116                         tagphysics  0.335004
# 94                              tagpvp  0.333761
# 225                      tagbullettime  0.332630
# 52                              tagwar  0.331529
# 300                tagturnbasedtactics  0.324078
# 69                        tagroguelike  0.314331
# 222                          tagrobots  0.307653
# 10                       tagfreetoplay  0.304665
# 72                           tagcomedy  0.302817
# 226                       tagisometric  0.302287
# 174                     tagreplayvalue  0.300559
# 140                       tagrealistic  0.291794
# 303                    tagconversation  0.288636
# 148                        tagepisodic  0.287583
# 23                        tageducation  0.285421
# 155                            tagdark  0.280450
# 234             taginventorymanagement  0.278983
# 103                 tagpostapocalyptic  0.277662
# 272  tagmusicbasedproceduralgeneration  0.274487
# 243                             tagpve  0.270267
# 322                     tagagriculture  0.267224
# 157                   taggrandstrategy  0.261466
# 241                           tag1990s  0.259573
# 22                  tagaudioproduction  0.254631
# 258                taglocalmultiplayer  0.250374
# 146                           tagshort  0.239963
# 114                       tagroguelite  0.239898
# 27                            tagmusic  0.237792
# 81                tagturnbasedstrategy  0.234390
# 251               tagrealtimewithpause  0.231192
# 9                         tagutilities  0.230682
# 269                        tagsoftware  0.229916
# 181                         tagtopdown  0.228667
# 302                          tagflight  0.225338
# 66                         tagtactical  0.222761
# 219                          tagremake  0.219075
# 278                          tagdemons  0.217828
# 254                        tagfootball  0.216921
# 178                        tagpolitics  0.213075
# 152                        tagcolorful  0.211901
# 306               tagsilentprotagonist  0.210504
# 86                           tagrhythm  0.207398
# 64                       tagpointclick  0.206557
# 231                          taghorses  0.205821
# 122                         tagparkour  0.205640
# 172                          tageco0my  0.202060
# 118                      taghistorical  0.198687
# 4                          maxdiscount  0.197543
# 273                   taginvestigation  0.190951
# 250                            taggolf  0.188922
# 33                     taghackandslash  0.188434
# 41                           tagpuzzle  0.187735
# 162          tagchooseyourownadventure  0.185953
# 76                            tagvoxel  0.183720
# 298                    tagexperimental  0.182300
# 161                            tagcrpg  0.175098
# 295                         tagamerica  0.169407
# 167                     tagdarkfantasy  0.165958
# 276                      tagunderwater  0.160964
# 26                           tagtrains  0.159644
# 73                   tagdungeoncrawler  0.158400
# 289                       tagmouseonly  0.157582
# 32                     tagtowerdefense  0.156854
# 45                         tagmoddable  0.155900
# 242                            tagmars  0.155856
# 110                     tagcompetitive  0.152241
# 325                            tagnsfw  0.150578
# 238                         tagpinball  0.146426
# 44                           taghorror  0.145629
# 138                        tagmilitary  0.144978
# 151                      tagfuturistic  0.143563
# 133                      tagworldwarii  0.142489
# 194            tagproceduralgeneration  0.140746
# 308                        taggambling  0.138226
# 268                      tagsoundtrack  0.137325
# 132                       tagcinematic  0.136851
# 180                tagspectaclefighter  0.124030
# 136                        tagrealtime  0.123849
# 189                         tagromance  0.122729
# 200                           tagblood  0.121739
# 96                     tagbasedona0vel  0.118295
# 115                   tagpixelgraphics  0.118152
# 135                        tagbeatemup  0.117603
# 2                            publisher  0.114549
# 281                tagdynamicnarration  0.111258
# 221                         tagmystery  0.109773
# 166                tagalternatehistory  0.108963
# 220                       tagteambased  0.108374
# 97                     tagsidescroller  0.108263
# 131                   tagtranshumanism  0.106890
# 70                          taghexgrid  0.106886
# 264                         tagoffroad  0.105519
# 228                       tagdarkhumor  0.104761
# 17                           tagracing  0.102944
# 291                        tagtutorial  0.101640
# 212                         taghacking  0.101163
# 164                 tagquicktimeevents  0.098937
# 46                               tag4x  0.097885
# 175                            tagcute  0.097691
# 31                          tagdriving  0.097114
# 320                     tagtacticalrpg  0.096935
# 223                tagguncustomization  0.095324
# 42                           tagmatch3  0.094755
# 144                         tagtrading  0.092344
# 253               tagfemaleprotagonist  0.092265
# 67                          tagsurreal  0.091197
# 248                            tagrome  0.091031
# 217                       tagdetective  0.087273
# 187                          tagparody  0.085080
# 34                          tagwestern  0.080452
# 109                              tag2d  0.074120
# 123                         tagdragons  0.072635
# 125                        tagthriller  0.068717
# 36                           tagsatire  0.066803
# 263               taggridbasedmovement  0.066326
# 274                          tagrunner  0.064021
# 95                        tagsteampunk  0.061519
# 59                            tagninja  0.061283
# 145                       tagactionrpg  0.061276
# 309                        tagspacesim  0.060885
# 134                      tagclassbased  0.059681
# 290              tagvillainprotagonist  0.059532
# 150                       tagshootemup  0.050917
# 270                         tagtrackir  0.048213
# 184                    tag4playerlocal  0.048030
# 201                         taggodgame  0.047866
# 239                tagtimemanipulation  0.045672
# 279                       tagdatingsim  0.042625
# 165                         tagcartoon  0.040168
# 100                 tagrealtimetactics  0.035041
# 21                taganimationmodeling  0.034563
# 266                     tagcultclassic  0.032983
# 271                     tagleveleditor  0.029870
# 315                             tagfmv  0.029113
# 20                     tagphotoediting  0.026366
# 147                            tagloot  0.025983
# 28                       tagplatformer  0.025942
# 29                     tagmetroidvania  0.024103
# 209                    tag3dplatformer  0.023130
# 224                         tagscience  0.020996
# 246                           tagnaval  0.019701
# 71                             tagmoba  0.018946
# 236                           tagcrime  0.018786
# 107                        taglorerich  0.017449
# 326                   tagtouchfriendly  0.017353
# 312                        taglemmings  0.016413
# 128                 tagactionadventure  0.008584
# 192                         tagesports  0.005065
# 197                        tagdi0saurs  0.004791
# 171                         tagwargame  0.003777
# 75                          tagsokoban  0.000000
# 336                   tagphilisophical  0.000000
# 78                         tagstarwars  0.000000
# 61                           tagbatman  0.000000
# 343                        taghardware  0.000000
# 316                         tagcycling  0.000000
# 208                      tagtimeattack  0.000000
# 210                       tagbenchmark  0.000000
# 335                           tagbikes  0.000000
# 319                       taglaracroft  0.000000
# 340                     tagfeaturefilm  0.000000
# 203                             tagmod -0.003449
# 284                      tagtimetravel -0.003525
# 129                       tagcyberpunk -0.008998
# 235                       tagdiplomacy -0.016967
# 143                        tagcartoony -0.017121
# 124                           tagmagic -0.027681
# 54                            tagheist -0.030051
# 245                        tag0nlinear -0.032163
# 186                       tagpolitical -0.037440
# 37                         tagrelaxing -0.044794
# 188                      tagbullethell -0.045615
# 179                tagtwinstickshooter -0.046530
# 98                       tagvisual0vel -0.047420
# 249                 tagmultipleendings -0.047638
# 191                       tagdystopian -0.048995
# 286                    tagsupernatural -0.053176
# 213                tagpuzzleplatformer -0.054249
# 230                           tagdrama -0.061571
# 85                        tagcomicbook -0.064022
# 176                       tag2dfighter -0.081520
# 255                          taglinear -0.092341
# 215                        tagrpgmaker -0.092948
# 159                        tagabstract -0.103714
# 112                          taggothic -0.107201
# 244                       taghanddrawn -0.116535
# 198                         tagcoldwar -0.122090
# 193                       tagnarration -0.126343
# 288              taginteractivefiction -0.143442
# 252                     tagcrowdfunded -0.161582
# 311                     tagstrategyrpg -0.168813
# 92                           tagarcade -0.170547
# 218                          tagmodern -0.171302
# 25                 tagsoftwaretraining -0.172354
# 24                    tagwebpublishing -0.172354
# 329                       tagtextbased -0.174038
# 119                           tagretro -0.175029
# 334                        tagspelling -0.181577
# 49                           tagtyping -0.181577
# 68                      tagpsychedelic -0.189904
# 190                             tag25d -0.200819
# 341                    tagsteammachine -0.201236
# 206                      tagconspiracy -0.203678
# 338                           tagfaith -0.204835
# 331                       tagwrestling -0.206566
# 47                        tagsuperhero -0.213683
# 211                     tagprogramming -0.213884
# 344                        tag360video -0.216035
# 304                     tagdocumentary -0.216121
# 195                     tagkickstarter -0.216868
# 207                       tagworldwari -0.244228
# 299                 taggamedevelopment -0.244255
# 333                  tagonrailsshooter -0.245422
# 287                     tagsplitscreen -0.256466
# 345                          tagvronly -0.259620
# 330                           tagotome -0.274639
# 318                     tagunderground -0.276251
# 339                  tagmysterydungeon -0.277467
# 232                             tag0ir -0.278746
# 142                           tagchess -0.281230
# 173                           tagmovie -0.307494
# 1                            developer -0.321290
# 282                      tagexperience -0.360336
# 323                        tagminigolf -0.362178
# 183                            tag6dof -0.371146
# 260                    taglovecraftian -0.371682
# 265                           tag1980s -0.387882
# 19                  tagvideoproduction -0.388236
# 113             tagcharacteractiongame -0.398376
# 35                        taggamemaker -0.399093
# 120                         tagvampire -0.409841
# 267          tagartificialintelligence -0.482192
# 149                        tagstylized -0.493957
# 314                            tagpool -0.502890
# 327                    tagvoicecontrol -0.518495
# 196                     tagscoreattack -0.520311
# 256                         tagbowling -0.596945
# 127                      tagminimalist -0.626063
# 313          tagasynchro0usmultiplayer -0.648229
# 233                           taglogic -0.721961
# 80                      taghidde0bject -0.966535
